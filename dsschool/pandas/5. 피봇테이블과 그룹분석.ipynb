# %% [markdown]
# ### pd > pivot(행인덱스, 열인덱스, 데이터)

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
df1.pivot("도시","연도","인구")
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
df1.set_index(["도시","연도"])[["인구"]].unstack()
# Out:
#            인구
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
df1.pivot(["지역", "도시"], "연도", "인구")
# Out:
# 연도           2005       2010       2015
# 지역  도시
# 경상권 부산  3512547.0  3393191.0  3448737.0
# 수도권 서울  9762546.0  9631482.0  9904312.0
#     인천        NaN   263203.0  2890451.0

# %% [markdown]
# ### 그룹분석
# - groupby()
# 1. 분석하고자 하는 시리즈나 데이터프레임에 groupby 메서드를 호출하여 그룹화를 한다.
# 2. 그룹 객체에 대해 그룹연산을 수행한다.

# %% [markdown]
# ### DatetimeIndex
# - 판다스에서 시계열 자료 생성하려면 DatetimeIndex 자료형으로 만들어야함
# - pd.to_datetime(); 날짜/시간을 나타내는 문자열 > datetime으로 바꿔줌

# %%
date_str = ["2018, 1, 1", "2018-01-01", "2018, 1, 5"]
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-05'], dtype='datetime64[ns]', freq=None)

# %%
np.random.seed(0)
s = pd.Series(np.random.randn(3), index=idx)
s
# Out:
# 2018-01-01    1.764052
# 2018-01-01    0.400157
# 2018-01-05    0.978738
# dtype: float64

# %%
pd.date_range("2018-04-01", "2018-04-30")
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2018-04-01", periods=30)
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# pd.date_range() freq인수
# - s: 초
# - T: 분
# - H: 시간
# - D: 일(day)
# - B: 주말이 아닌 평일
# - W: 주(일요일)
# - W-MON: 주(월요일)
# - M: 각 달(month)의 마지막 날
# - MS: 각 달의 첫날
# - BM: 주말이 아닌 평일 중에서 각 달의 마지막 날
# - BMS: 주말이 아닌 평일 중에서 각 달의 첫날
# - WOM-2THU: 각 달의 두번째 목요일
# - Q-JAN: 각 분기의 첫달의 마지막 날
# - Q-DEC: 각 분기의 마지막 달의 마지막 날

# %%
pd.date_range(start="2020-01-01", periods=60, freq="B")
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-03',
#                '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-17', '2020-02-18', '2020-02-19',
#                '2020-02-20', '2020-02-21', '2020-02-24', '2020-02-25',
#                '2020-02-26', '2020-02-27', '2020-02-28', '2020-03-02',
#                '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06',
#                '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
# ...

# %%
# pd.date_range(start="2020-01-01", periods=60, freq="W-MON")

# %% [markdown]
# shift 연산 ; 시계열 데이터의 인덱스는 시간이나 날짜를 나타내기 때문에 날짜 이동 등의 다양한 연산이 가능

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(4), index = pd.date_range(
        "2020-01-01", periods=4, freq="M"))
ts
# Out:
# 2020-01-31    1.764052
# 2020-02-29    0.400157
# 2020-03-31    0.978738
# 2020-04-30    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(3)
# Out:
# 2020-01-31         NaN
# 2020-02-29         NaN
# 2020-03-31         NaN
# 2020-04-30    1.764052
# Freq: M, dtype: float64

# %%
ts.shift(0)
# Out:
# 2020-01-31    1.764052
# 2020-02-29    0.400157
# 2020-03-31    0.978738
# 2020-04-30    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(-1)
# Out:
# 2020-01-31    0.400157
# 2020-02-29    0.978738
# 2020-03-31    2.240893
# 2020-04-30         NaN
# Freq: M, dtype: float64

# %% [markdown]
# resample()
# - 날짜가 아닌 시/분 단위에서는 구간위 왼쪽 한계값(가장 빠른 값)은 포함하고 오른쪽 한계값(가장 늦은 값)은 포함하지 않는다.

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range(
    "2018-1-1", periods=100, freq="D"))
ts.tail(20)
# Out:
# 2018-03-22    1.488252
# 2018-03-23    1.895889
# 2018-03-24    1.178780
# 2018-03-25   -0.179925
# 2018-03-26   -1.070753
# 2018-03-27    1.054452
# 2018-03-28   -0.403177
# 2018-03-29    1.222445
# 2018-03-30    0.208275
# 2018-03-31    0.976639
# 2018-04-01    0.356366
# 2018-04-02    0.706573
# 2018-04-03    0.010500
# 2018-04-04    1.785870
# 2018-04-05    0.126912
# 2018-04-06    0.401989
# 2018-04-07    1.883151
# 2018-04-08   -1.347759
# 2018-04-09   -1.270485
# 2018-04-10    0.969397
# Freq: D, dtype: float64

# %%
ts.resample('W').mean()
# Out:
# 2018-01-07    0.305776
# 2018-01-14    0.629064
# 2018-01-21   -0.006910
# 2018-01-28    0.277065
# 2018-02-04   -0.144972
# 2018-02-11   -0.496299
# 2018-02-18   -0.474473
# 2018-02-25   -0.201222
# 2018-03-04   -0.775142
# 2018-03-11    0.052868
# 2018-03-18   -0.450379
# 2018-03-25    0.601892
# 2018-04-01    0.334893
# 2018-04-08    0.509605
# 2018-04-15   -0.150544
# Freq: W-SUN, dtype: float64

# %%
ts.resample('M').first()
# Out:
# 2018-01-31    1.867558
# 2018-02-28    0.156349
# 2018-03-31   -1.726283
# 2018-04-30    0.356366
# Freq: M, dtype: float64

# %%
ts = pd.Series(np.random.randn(60), index=pd.date_range(
    "2018-1-1", periods=60, freq="T"))
ts.head(20)
# Out:
# 2018-01-01 00:00:00   -1.173123
# 2018-01-01 00:01:00    1.943621
# 2018-01-01 00:02:00   -0.413619
# 2018-01-01 00:03:00   -0.747455
# 2018-01-01 00:04:00    1.922942
# 2018-01-01 00:05:00    1.480515
# 2018-01-01 00:06:00    1.867559
# 2018-01-01 00:07:00    0.906045
# 2018-01-01 00:08:00   -0.861226
# 2018-01-01 00:09:00    1.910065
# 2018-01-01 00:10:00   -0.268003
# 2018-01-01 00:11:00    0.802456
# 2018-01-01 00:12:00    0.947252
# 2018-01-01 00:13:00   -0.155010
# 2018-01-01 00:14:00    0.614079
# 2018-01-01 00:15:00    0.922207
# 2018-01-01 00:16:00    0.376426
# 2018-01-01 00:17:00   -1.099401
# 2018-01-01 00:18:00    0.298238
# 2018-01-01 00:19:00    1.326386
# Freq: T, dtype: float64

# %%
ts.resample('10T').sum()
# Out:
# 2018-01-01 00:00:00    6.835324
# 2018-01-01 00:10:00    3.764630
# 2018-01-01 00:20:00    0.776495
# 2018-01-01 00:30:00   -0.538336
# 2018-01-01 00:40:00    1.828234
# 2018-01-01 00:50:00    0.167957
# Freq: 10T, dtype: float64

# %%
ts.resample('10T', closed="right").sum() # 오른쪽 한계값을 구간에 포함하고 싶을 때
# Out:
# 2017-12-31 23:50:00   -1.173123
# 2018-01-01 00:00:00    7.740444
# 2018-01-01 00:10:00    3.338065
# 2018-01-01 00:20:00    0.835217
# 2018-01-01 00:30:00    2.480654
# 2018-01-01 00:40:00   -0.653363
# 2018-01-01 00:50:00    0.266409
# Freq: 10T, dtype: float64

# %%
ts.resample('5T').ohlc()
# Out:
#                          open      high       low     close
# 2018-01-01 00:00:00 -1.173123  1.943621 -1.173123  1.922942
# 2018-01-01 00:05:00  1.480515  1.910065 -0.861226  1.910065
# 2018-01-01 00:10:00 -0.268003  0.947252 -0.268003  0.614079
# 2018-01-01 00:15:00  0.922207  1.326386 -1.099401  1.326386
# 2018-01-01 00:20:00 -0.694568  1.849264 -0.694568  0.672295
# 2018-01-01 00:25:00  0.407462  0.539249 -0.769916  0.031831
# 2018-01-01 00:30:00 -0.635846  0.676433 -0.635846  0.396007
# 2018-01-01 00:35:00 -1.093062  0.635031 -1.491258  0.635031
# 2018-01-01 00:40:00  2.383145  2.383145 -1.315907 -1.315907
# 2018-01-01 00:45:00 -0.461585  1.713343 -0.826439 -0.826439
# 2018-01-01 00:50:00 -0.098453  1.126636 -1.147469 -1.147469
# 2018-01-01 00:55:00 -0.437820  1.929532 -0.498032  0.087551

# %% [markdown]
# date 자료형 시리즈 > dt 접근자

# %%
s = pd.Series(pd.date_range("2020-12-25", periods=100, freq="D"))
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %%
s.dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
#       ...
# 95    2021
# 96    2021
# 97    2021
# 98    2021
# 99    2021
# Length: 100, dtype: int64

# %%
s.dt.day
# Out:
# 0     25
# 1     26
# 2     27
# 3     28
# 4     29
#       ..
# 95    30
# 96    31
# 97     1
# 98     2
# 99     3
# Length: 100, dtype: int64

# %%
s.dt.strftime("%Y년 %m월 %d일")
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object
