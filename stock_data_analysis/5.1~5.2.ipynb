# %% [markdown]
# #### 5.1 네이버 금융 데이터로 시세 데이터베이스 구축하기

# %% [markdown]
# ##### 5장에서 할 것
# > 1. 마리아디비에 매일 네이버 금융을 웹 스크래핑해서 업데이트하기
# > 2. 일별 시세 조회 API 만들기
# > - cursor ;  https://pymysql.readthedocs.io/en/latest/modules/cursors.html

# %%
import matplotlib.pyplot as plt
from Investar import Analyzer
import pymysql

# %%
connection = pymysql.connect(host='localhost', port=3306, db='investar', user='root', passwd='1234', autocommit=True)
cursor = connection.cursor()
cursor.execute("SELECT VERSION();")
result = cursor.fetchone() # 실행결과를 튜플로 받음

print("MariaDB version : {}".format(result))

connection.close()
# Out:
# MariaDB version : ('10.5.9-MariaDB',)
