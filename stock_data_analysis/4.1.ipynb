# %% [markdown]
# #### 4.1 팬더스로 상장법인 목록 읽기

# %% [markdown]
# ##### read_html() ; HTML 파일 내부에 존재하는 테이블 태그를 분석하여 데이터프레임으로 변환해줌.
# ##### 결과값으로 데이터프레임 객체를 원소로 가지는 리스트를 반환한다. > 리스트의 첫번째 값을 데이터프레임으로 가지려고 [0]..

# %%
import pandas as pd
krx_list = pd.read_html('C:/Users/fyd11/Downloads/krx_list.xls')
krx_list # 리스트
# Out:
# [            회사명    종목코드                     업종  \
#  0     SK바이오사이언스  302440  기초 의약물질 및 생물학적 제제 제조업
#  1         바이오다인  314930             의료용 기기 제조업
#  2      DB금융스팩9호  367360             금융 지원 서비스업
#  3         네오이뮨텍  950220        자연과학 및 공학 연구개발업
#  4        화승알앤에이  378850          자동차 신품 부품 제조업
#  ...         ...     ...                    ...
#  2429     CJ대한통운     120              도로 화물 운송업
#  2430      메리츠화재      60                    보험업
#  2431         경방      50                 종합 소매업
#  2432      유수홀딩스     700    회사 본부 및 경영 컨설팅 서비스업
#  2433   한진중공업홀딩스    3480      연료용 가스 제조 및 배관공급업
#
#                                                     주요제품         상장일  결산월  \
#  0                                            백신 제품 및 제제  2021-03-18  12월
#  1                                       액상세포검사 장비 및 소모품  2021-03-17  12월
#  2                                             기업인수 및 합병  2021-03-16  12월
#  3                                                 면역항암제  2021-03-16  12월
# ...

# %%
type(krx_list)
# Out:
# list

# %%
# krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)
krx_list[0]
# Out:
#             회사명    종목코드                     업종  \
# 0     SK바이오사이언스  302440  기초 의약물질 및 생물학적 제제 제조업
# 1         바이오다인  314930             의료용 기기 제조업
# 2      DB금융스팩9호  367360             금융 지원 서비스업
# 3         네오이뮨텍  950220        자연과학 및 공학 연구개발업
# 4        화승알앤에이  378850          자동차 신품 부품 제조업
# ...         ...     ...                    ...
# 2429     CJ대한통운  000120              도로 화물 운송업
# 2430      메리츠화재  000060                    보험업
# 2431         경방  000050                 종합 소매업
# 2432      유수홀딩스  000700    회사 본부 및 경영 컨설팅 서비스업
# 2433   한진중공업홀딩스  003480      연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                            백신 제품 및 제제  2021-03-18  12월
# 1                                       액상세포검사 장비 및 소모품  2021-03-17  12월
# 2                                             기업인수 및 합병  2021-03-16  12월
# 3                                                 면역항암제  2021-03-16  12월
# ...

# %%
df = pd.read_html('https://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13')[0] # 결과값을 데이터프레임으로 받으려고

# %%
df
# Out:
#             회사명    종목코드               업종  \
# 0           DSR  155660      1차 비철금속 제조업
# 1         GS글로벌    1250        상품 종합 도매업
# 2     HDC현대산업개발  294870           건물 건설업
# 3        KG동부제철   16380        1차 철강 제조업
# 4         KG케미칼    1390      기초 화학물질 제조업
# ...         ...     ...              ...
# 2429         코셋  189350   통신 및 방송 장비 제조업
# 2430         툴젠  199800  자연과학 및 공학 연구개발업
# 2431   플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 2432   한국미라클피플사  331660      기타 화학제품 제조업
# 2433        휴벡셀  212310       의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                                                합섬섬유로프  2013-05-15  12월
# 1     수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 2                                외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 3     철강재(냉연강판,아연도강판,칼라강판,석도강판,선재류,강관,형강,봉강),비철금속 제조,도매  1986-02-03  12월
# 4                             콘크리트혼화제, 비료, 친환경농자재, 수처리제  1989-08-25  12월
# ...

# %%
df['종목코드'] = df['종목코드'].map('{:06d}'.format)
df = df.sort_values(by='종목코드')
df
# Out:
#              회사명    종목코드                      업종  \
# 924         동화약품  000020                 의약품 제조업
# 1510       KR모터스  000040          그외 기타 운송장비 제조업
# 1517          경방  000050                  종합 소매업
# 1537       메리츠화재  000060                     보험업
# 33         삼양홀딩스  000070                  기타 금융업
# ...          ...     ...                     ...
# 1006         SNK  950180          소프트웨어 개발 및 공급업
# 1645         미투젠  950190          소프트웨어 개발 및 공급업
# 1668         소마젠  950200  그외 기타 전문, 과학 및 기술 서비스업
# 1876  프레스티지바이오파마  950210         자연과학 및 공학 연구개발업
# 2218       네오이뮨텍  950220         자연과학 및 공학 연구개발업
#
#                                            주요제품         상장일  결산월  \
# 924                               의약품 제조,판매,수출입  1976-03-24  12월
# 1510                            이륜차(오토바이) 제조,도매  1976-05-25  12월
# 1517  섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 1537                           손해보험(화재,해상,운송보험)  1956-07-02  12월
# ...
